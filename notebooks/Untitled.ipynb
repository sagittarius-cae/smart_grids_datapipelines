# %%
#%run ../src/generate_syntetic_datasets.py
# Out:
# Iniciando generación normalizada de 15,000,000 registros...
# Carpeta 'data_lakehouse' creada exitosamente.
#
# [1/2] Generando catálogo maestro de infraestructura (data_lakehouse/smart_grids_infrastructure.csv)...
# -> ¡Guardado! data_lakehouse/smart_grids_infrastructure.csv con 75,000 medidores catalogados.
#
# [2/2] Generando bloques transaccionales de telemetría para smart_meters...
# Generando bloque de telemetría 1/3...
# Inyectando registros duplicados controlados en el bloque 1...
# -> ¡Guardado! data_lakehouse/smart_meters_telemetry_part_1.csv (5,015,000 filas con anomalías de ingesta)
# Generando bloque de telemetría 2/3...
# -> ¡Guardado! data_lakehouse/smart_meters_telemetry_part_2.csv (5,000,000 filas con anomalías de ingesta)
# Generando bloque de telemetría 3/3...
# -> ¡Guardado! data_lakehouse/smart_meters_telemetry_part_3.csv (4,999,976 filas con anomalías de ingesta)
#
# ¡Pipeline listo! Todos los archivos fueron depositados en la carpeta 'data_lakehouse'.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
smartgrid_df = pd.read_csv('/app/data_lakehouse/smart_grids_infrastructure.csv')
# Inspect raw schema and initial rows

# %%
print(smartgrid_df.shape)
# Out:
# (75000, 6)

# %%
print(smartgrid_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Meter_ID        75000 non-null  str
#  1   Country         75000 non-null  str
#  2   Region          75000 non-null  str
#  3   Substation_ID   75000 non-null  str
#  4   Feeder_Line_ID  75000 non-null  str
#  5   Area_Profile    75000 non-null  str
# dtypes: str(6)
# memory usage: 3.4 MB
# None

# %%
print(smartgrid_df.head(2))
# Out:
#        Meter_ID Country    Region  Substation_ID Feeder_Line_ID Area_Profile
# 0  METER-000001   Spain    Madrid  SUB-GRID-0137      FEEDER-27   Industrial
# 1  METER-000002  Brazil  Amazonas  SUB-GRID-0030      FEEDER-30        Rural
